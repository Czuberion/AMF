# %%
import pandas as pd

# %%
df = pd.read_csv('../../../../data/raw/Food_Time_Data_Set.csv')

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'temperature', 'humidity', 'precipitation', 'weather_description',
#        'Unnamed: 14', 'Traffic_Level', 'Distance (km)', 'TARGET'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Ensure TARGET column is numeric
df['TARGET'] = pd.to_numeric(df['TARGET'], errors='coerce')

# Drop rows with NaN values in Delivery_person_Age or TARGET
df_clean = df.dropna(subset=['Delivery_person_Age', 'TARGET'])

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(df_clean['Delivery_person_Age'], df_clean['TARGET'], alpha=0.5)
plt.title('Impact of Delivery Person Age on delivery time')
plt.xlabel('Delivery Person Age')
plt.ylabel('TARGET')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_clean['humidity'], df_clean['TARGET'], alpha=0.5)
plt.title('Impact of Humidity on delivery time')
plt.xlabel('Humidity')
plt.ylabel('TARGET')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Plotting Distance vs TARGET with color coding for weather_description
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x='Distance (km)', y='TARGET', hue='weather_description', palette='viridis', alpha=0.5)
plt.title('Impact of Distance on delivery time with Weather Description')
plt.xlabel('Distance (km)')
plt.ylabel('TARGET')
plt.grid(True)
plt.legend(title='Weather Description', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df_clean, x='Traffic_Level', y='TARGET', palette='Set3')
plt.title('Impact of Traffic Level on delivery time')
plt.xlabel('Traffic Level')
plt.ylabel('TARGET')
plt.grid(True)
plt.show()
